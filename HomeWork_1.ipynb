# %% [markdown]
# ## Домашнее задание к лекции "Основы Python"

# %% [markdown]
# ### Задание 1
# - Даны 2 переменных, в которых хранятся строки произвольной длины: phrase_1 и phrase_2.
# Напишите код, который проверяет какая из этих строк длиннее.

# %%
string1 = input('Введите строку 1: ')
string2 = input('Введите строку 2: ')

if len(string1) > len(string2):
    print('Строка 1 длиннее строки 2')
elif len(string1) < len(string2):
    print('Строка 1 короче строки 2')
else:
    print('Строки равной длины!')
# Out:
# Введите строку 1: фывапр
# Введите строку 2: фыв
# Строка 1 длиннее строки 2

# %% [markdown]
# ### Задание 2
# - Дана переменная, в которой хранится четырехзначное число (год). Необходимо написать программу, которая выведет, является ли данный год високосным или обычным.

# %%
year = int(input('Введите год: '))
if year % 4 == 0:
    print(f'Год {year} високосный')
else:
    print(f'Год {year} обычный')
# Out:
# Введите год: 2018
# Год 2018 обычный

# %% [markdown]
# ### Задание 3
# - Необходимо написать программу, которая будет запрашивать у пользователя месяц и дату рождения и выводить соответствующий знак зодиака.

# %%
mounths = ['март','апрель','май','июнь','июль','август','сентябрь','октябрь','ноябрь','декабрь','январь','февраль']
print(mounths)
# Out:
# ['март', 'апрель', 'май', 'июнь', 'июль', 'август', 'сентябрь', 'октябрь', 'ноябрь', 'декабрь', 'январь', 'февраль']

# %%
def what_zodiak(d, m):
    if m == 'март':
        if d < 21 and d > 0:
            print('Ваш знак зодиака: "Рыбы"')
        elif d >= 21 and d <= 31:
            print('Ваш знак зодиака: "Овен"')
        else:
            print('Некорректная дата')
    if m == 'апрель':
        if d < 20 and d > 0:
            print('Ваш знак зодиака: "Овен"')
        elif d >= 20 and d <= 30:
            print('Ваш знак зодиака: "Телец"')
        else:
            print('Некорректная дата')
    if m == 'май':
        if d < 21 and d > 0:
            print('Ваш знак зодиака: "Телец"')
        elif d >= 21 and d <= 31:
            print('Ваш знак зодиака: "Близнецы"')
        else:
            print('Некорректная дата')
    if m == 'июнь':
        if d < 22 and d > 0:
            print('Ваш знак зодиака: "Близнецы"')
        elif d >= 22 and d <= 30:
            print('Ваш знак зодиака: "Рак"')
        else:
            print('Некорректная дата')
    if m == 'июль':
        if d < 23 and d > 0:
            print('Ваш знак зодиака: "Рак"')
        elif d >= 23 and d <= 31:
            print('Ваш знак зодиака: "Лев"')
        else:
            print('Некорректная дата')
    if m == 'август':
        if d < 23 and d > 0:
            print('Ваш знак зодиака: "Лев"')
        elif d >= 23 and d <= 31:
            print('Ваш знак зодиака: "Дева"')
        else:
            print('Некорректная дата')
    if m == 'сентябрь':
        if d < 23 and d > 0:
            print('Ваш знак зодиака: "Дева"')
        elif d >= 23 and d <= 30:
            print('Ваш знак зодиака: "Весы"')
        else:
            print('Некорректная дата')
    if m == 'октябрь':
        if d < 24 and d > 0:
            print('Ваш знак зодиака: "Весы"')
        elif d >= 24 and d <= 31:
            print('Ваш знак зодиака: "Скорпион"')
        else:
            print('Некорректная дата')
    if m == 'ноябрь':
        if d < 23 and d > 0:
            print('Ваш знак зодиака: "Скорпион"')
        elif d >= 23 and d <= 30:
            print('Ваш знак зодиака: "Стрелец"')
        else:
            print('Некорректная дата')
    if m == 'декабрь':
        if d < 22 and d > 0:
            print('Ваш знак зодиака: "Стрелец"')
        elif d >= 22 and d <= 31:
            print('Ваш знак зодиака: "Козерог"')
        else:
            print('Некорректная дата')
    if m == 'январь':
        if d < 21 and d > 0:
            print('Ваш знак зодиака: "Козерог"')
        elif d >= 21 and d <= 31:
            print('Ваш знак зодиака: "Водолей"')
        else:
            print('Некорректная дата')
    if m == 'февраль':
        if d < 19 and d > 0:
            print('Ваш знак зодиака: "Водолей"')
        elif d >= 19 and d <= 29:
            print('Ваш знак зодиака: "Рыбы"')
        else:
            print('Некорректная дата')

day = input('Введите день Вашего роджения (число от 1 до 31): ')
day = int(day)
mounth = input('Введите месяц Вашего роджения (март, апрель итд...): ')
mounth = mounth.lower()

if mounth in mounths:
    what_zodiak(day, mounth)
else:
    print('Некорректный месяц.')
# Out:
# Введите день Вашего роджения (число от 1 до 31): 5
# Введите месяц Вашего роджения (март, апрель итд...): август
# Ваш знак зодиака: "Лев"

# %% [markdown]
# ### Задание 4
# Вам нужно написать программу для подбора упаковок по размерам товара. Размеры хранятся в переменных (в сантиметрах):
#
# - width = 10
# - length = 205
# - height = 5
#
# Используйте следующие правила:
#
# если каждое из трех измерений менее 15 сантиметров, то выведите на экран “Коробка №1”;
# если хотя бы одно из измерений больше 15 сантиметров, но менее 50 сантиметров, то выводите “Коробка №2”;
# если длина товара больше 2 метров, то выводите “Упаковка для лыж”;
# во всех остальных случаях выводите “Стандартная коробка №3”.

# %%
# w - ширина, l - длина, h - высота
print('Введите габариты коробки в см.: ')
w,l,h = int(input('Введите ширину: ')), int(input('Введите длину: ')), int(input('Введите высоту: '))
if w <= 15 and l <= 15 and h <= 15:
    print('Коробка №1')
elif l >= 200:
    print('Коробка для лыж')
elif (w > 15 and w < 50) or (l > 15 and l < 50) or (h > 15 and h < 50):
    print('Коробка №2')
else:
    print('Стандартная коробка №3')
# Out:
# Введите габариты коробки в см.:
# Введите ширину: 220
# Введите длину: 4
# Введите высоту: 23
# Коробка №2

# %% [markdown]
# ### Задание 5 (необязательное)
# Дана переменная, в которой хранится шестизначное число (номер проездного билета). Напишите программу, которая будет определять, является ли данный билет “счастливым”. Билет считается счастливым, если сумма первых трех цифр совпадает с суммой последних трех цифр номера.
#
# Примеры работы программы:
#
# number = 123456
# Результат:
# Неасчастливый билет
#
# number = 123321
# Результат:
# Счастливый билет

# %%
# t - ticket number
t = input('Введите номер билета (6 цифр) ')

t1 = 0 # переменная для суммы первой половины цифр билета
t2 = 0 # переменная для суммы второй половины цифр билета

for i in range(3): # получаем сумму первых 3 знаков билета, нумерация с 0, ДО не включительно.
    t1 = t1 + int(t[i])
#print(t1)
for i in range(3, 6): # получаем сумму вторых 3 знаков билета
    t2 = t2 + int(t[i])
#print(t2)

if t1 == t2:
    print('Билет счастливый!')
else:
    print('Билет обычный...')
# Out:
# Введите номер билета (6 цифр) 178196
# Билет счастливый!

# %% [markdown]
# ### Задание 6 (необязательное)
# Напишите программу, которая сможет вычислять площади трех фигур (круг, треугольник и прямоугольник). Тип фигуры запрашиваем через пользовательский ввод, после чего делаем запрос характеристик фигуры:
#
# если пользователь выбрал круг, запрашиваем его радиус,
# если треугольник – длины трех его сторон;
# если прямоугольник – длины двух его сторон.

# %%
import math as m

shape_type = int(input("""
Введите тип фигуры (цифру):
1 - круг
2 - треугольник
3 - прямоугольник
"""))

if shape_type == 1:
    r = float(input('Введите радиус: '))
    f = float(input('Введите радиус: '))
    print(f'Площадь круга равна: { round(m.pi * ( r ** 2 ), 2) }')
elif shape_type == 2:
    a = float(input('Введите длину стороны а: '))
    b = float(input('Введите длину стороны b: '))
    c = float(input('Введите длину стороны c: '))
    p = (a + b + c) / 2 # полупериметр
    print('Площадь треугольника равна:', round(m.sqrt(p*(p-a)*(p-b)*(p-c)),2))
elif shape_type == 3:
    a = float(input('Введите длину стороны а: '))
    b = float(input('Введите длину стороны b: '))
    print('Площадь треугольника равна:', a * b )
else:
     print('Не корректный тип фигуры')
# Out:
# Введите тип фигуры (цифру):
# 1 - круг
# 2 - треугольник
# 3 - прямоугольник
# 2
# Введите длину стороны а: 4
# Введите длину стороны b: 3.6
# Введите длину стороны c: 2.4
# Площадь треугольника равна: 4.27
